# %%
class DynamicArray:  
    def __init__(self):
        self.capacity = 1  # capacidad inicial
        self.length = 0    # elementos actuales
        self.data = [None] * self.capacity

    def append(self, value): # 0 1 2
        # si está lleno, realocar con el doble de capacidad
        if self.length == self.capacity:
            self._resize(2 * self.capacity)
        self.data[self.length] = value
        self.length += 1

    def _resize(self, new_cap):
        new_data = [None] * new_cap
        for i in range(self.length):
            new_data[i] = self.data[i]
        self.data = new_data
        self.capacity = new_cap

# %%
# Create the Dynamic Array Object
arr = DynamicArray()

# %%
type(arr)
# Out:
# __main__.DynamicArray

# %%
for i in range(5):
    arr.append(i)

# %%
print(f"Data: {arr.data}")
# Out:
# Data: [0, 1, 2, 3, 4, None, None, None]

# %%
print(f"Length: {arr.length}")
# Out:
# Length: 5

# %%
print(f"Capacity: {arr.capacity}")
# Out:
# Capacity: 8

# %%
lista = [0, 1, 2, 3, 4, None, None, None]

# %%
type(lista)
# Out:
# list

# %%
len(lista)
# Out:
# 8

# %%
print(lista)
# Out:
# [0, 1, 2, 3, 4, None, None, None]

# %%
lista.append("Hola Mundo")

# %%
len(lista)
# Out:
# 9

# %%
print(lista)
# Out:
# [0, 1, 2, 3, 4, None, None, None, 'Hola Mundo']
