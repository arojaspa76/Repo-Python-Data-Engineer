# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

# %%
class BinarySearchTree:
    def __init__(self):
        self.root = None

    def insert(self, value):
        if not self.root:
            self.root = Node(value)
        else:
            self._insert_rec(self.root, value)

    def _insert_rec(self, current, value):
        if value < current.value:
            if current.left:
                self._insert_rec(current.left, value)
            else:
                current.left = Node(value)
        else:
            if current.right:
                self._insert_rec(current.right, value)
            else:
                current.right = Node(value)

    def search(self, value):
        return self._search_rec(self.root, value)

    def _search_rec(self, current, value):
        if current is None:
            return False
        if value == current.value:
            return True
        elif value < current.value:
            return self._search_rec(current.left, value)
        else:
            return self._search_rec(current.right, value)

# %%
bst = BinarySearchTree()

# %%
type(bst)
# Out:
# __main__.BinarySearchTree

# %%
print(f"Raíz inicial: {bst.root}") # Resultado: None
# Out:
# Raíz inicial: None

# %%
valores = [50, 30, 70, 20, 40, 60, 80]

# %%
for v in valores:
    bst.insert(v)

# %%
print(bst)
# Out:
# <__main__.BinarySearchTree object at 0x74f2d116c410>

# %%
# Búsqueda exitosa
encontrado = bst.search(25)
print(f"¿40 está en el árbol? {encontrado}") # Resultado: True
# Out:
# ¿40 está en el árbol? False
